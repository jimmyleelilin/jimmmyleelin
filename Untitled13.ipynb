# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data=StringIO()
export_graphviz(dtree,out_file=dot_data,
               filled=True,rounded=True,
               special_characters=True)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import tensorflow

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-88d96843a926> in <module>()
# ----> 1 import keras
#
# ImportError: No module named keras

# %%
import numpy as np
A=np.array([1,2,3])
B=np.array([4,3,0])
print("A+B= ",np.add(A,B))
print("A-B= ",np.subtract(A,B))
# Out:
# ('A+B= ', array([5, 5, 3]))
# ('A-B= ', array([-3, -1,  3]))

# %%
C=np.array([[1,2,3],[4,5,6]])
D=np.array([[4,3,9,9],[1,1,2,2],[4,2,1,1]])
print("np.dot(C,D)=",np.dot(C,D))
print("np.matul(C,D)=" ,np.matmul(C,D))
print("C@D=" ,np.matmul(C,D))
#print("np.matul(C,D)=" ,C@D)
print("np.multiply(D,D)=" ,np.multiply(D,D))
print("D*D=" ,D*D)
# Out:
# ('np.dot(C,D)=', array([[18, 11, 16, 16],
#        [45, 29, 52, 52]]))
# ('np.matul(C,D)=', array([[18, 11, 16, 16],
#        [45, 29, 52, 52]]))
# ('C@D=', array([[18, 11, 16, 16],
#        [45, 29, 52, 52]]))
# ('np.multiply(D,D)=', array([[16,  9, 81, 81],
#        [ 1,  1,  4,  4],
#        [16,  4,  1,  1]]))
# ('D*D=', array([[16,  9, 81, 81],
#        [ 1,  1,  4,  4],
#        [16,  4,  1,  1]]))

# %%
conda install keras
# Out:
#   File "<ipython-input-39-a71dc67ec96d>", line 1
#     conda install keras
#                 ^
# SyntaxError: invalid syntax
